# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df = df.iloc[:,[3,4]].values

# %%
df[0:5]
# Out:
# array([[15, 39],
#        [15, 81],
#        [16,  6],
#        [16, 77],
#        [17, 40]])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
linkage = ["ward", "complete", "average", "single"]

# %%
from sklearn.cluster import AgglomerativeClustering

for i in range(len(linkage)):
  hc = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = linkage[i])
  y_hc = hc.fit_predict(df)

  print("Using Linkage :",linkage[i])
  #Clustering metrics
  clustering_score = davies_bouldin_score(df, y_hc)
  print("clustering_score : ",clustering_score)

  

  # Visualising the clusters
  plt.scatter(df[y_hc == 0, 0], df[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
  plt.scatter(df[y_hc == 1, 0], df[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
  plt.scatter(df[y_hc == 2, 0], df[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
  plt.scatter(df[y_hc == 3, 0], df[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
  plt.scatter(df[y_hc == 4, 0], df[y_hc == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
  plt.title('Agglomerative Clustering')

  plt.legend()
  plt.show()
# Out:
# Using Linkage : ward
# clustering_score :  0.5782207452369454
# Using Linkage : complete
# clustering_score :  0.5782207452369453
# Using Linkage : average
# clustering_score :  0.6425127774689778
# Using Linkage : single
# clustering_score :  0.47871881864476584

# %%
from sklearn.cluster import AgglomerativeClustering

for i in range(len(linkage)):
  hc = AgglomerativeClustering(n_clusters = 4, affinity = 'euclidean', linkage = linkage[i])
  y_hc = hc.fit_predict(df)

  print("Using Linkage :",linkage[i])
  #Clustering metrics
  clustering_score = davies_bouldin_score(df, y_hc)
  print("clustering_score : ",clustering_score)

  # Visualising the clusters
  plt.scatter(df[y_hc == 0, 0], df[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
  plt.scatter(df[y_hc == 1, 0], df[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
  plt.scatter(df[y_hc == 2, 0], df[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
  plt.scatter(df[y_hc == 3, 0], df[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
  plt.title('Agglomerative Clustering')

  plt.legend()
  plt.show()
# Out:
# Using Linkage : ward
# clustering_score :  0.6712836786400213
# Using Linkage : complete
# clustering_score :  0.6712836786400214
# Using Linkage : average
# clustering_score :  0.6917976893476394
# Using Linkage : single
# clustering_score :  0.4243161520187781

# %%
from sklearn.cluster import AgglomerativeClustering

for i in range(len(linkage)):
  hc = AgglomerativeClustering(n_clusters = 3, affinity = 'euclidean', linkage = linkage[i])
  y_hc = hc.fit_predict(df)

  print("Using Linkage :",linkage[i])
  #Clustering metrics
  clustering_score = davies_bouldin_score(df, y_hc)
  print("clustering_score : ",clustering_score)

  # Visualising the clusters
  plt.scatter(df[y_hc == 0, 0], df[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
  plt.scatter(df[y_hc == 1, 0], df[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
  plt.scatter(df[y_hc == 2, 0], df[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
  plt.title('Agglomerative Clustering')

  plt.legend()
  plt.show()
# Out:
# Using Linkage : ward
# clustering_score :  0.7068435076376502
# Using Linkage : complete
# clustering_score :  0.7068435076376502
# Using Linkage : average
# clustering_score :  0.715276820248462
# Using Linkage : single
# clustering_score :  0.3646616939688934

# %%
from sklearn.cluster import AgglomerativeClustering

for i in range(len(linkage)):
  hc = AgglomerativeClustering(n_clusters = 2, affinity = 'euclidean', linkage = linkage[i])
  y_hc = hc.fit_predict(df)

  print("Using Linkage :",linkage[i])
  #Clustering metrics
  clustering_score = davies_bouldin_score(df, y_hc)
  print("clustering_score : ",clustering_score)

  

  # Visualising the clusters
  plt.scatter(df[y_hc == 0, 0], df[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
  plt.scatter(df[y_hc == 1, 0], df[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
  plt.title('Agglomerative Clustering')

  plt.legend()
  plt.show()
# Out:
# Using Linkage : ward
# clustering_score :  1.3734011244003579
# Using Linkage : complete
# clustering_score :  1.3734011244003579
# Using Linkage : average
# clustering_score :  0.8569473078545492
# Using Linkage : single
# clustering_score :  0.36984369456121996
